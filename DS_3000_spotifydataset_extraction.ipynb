# %%
import requests
import pandas as pd
import sys
import spotipy
import spotipy.util as util

# %%
#code for authenticating a user (needed to access spotify information about a specific user)

scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username, scope, client_id = 'aad38808a7a746109ec09ba4c75bd7b5', 
                                  client_secret = '19af4190d41e4392a5ce461a370492e2', redirect_uri = 'http://google.com/')

# %%
#spotipy object to access specific user data
sp = spotipy.Spotify(auth=token)

# %%
#gets the first 50 tracks this user's saved library
user_tracks = sp.current_user_saved_tracks(limit=50,offset=0)

# %%
#puts the track information into a dataframe, minus the limit, next, offset, previous, and total
#attributes becuase they will not be useful in our later analysis
tracks_df = pd.DataFrame(user_tracks)
tracks_df = tracks_df.drop('limit',axis=1)
tracks_df = tracks_df.drop('next',axis=1)
tracks_df = tracks_df.drop('offset',axis=1)
tracks_df = tracks_df.drop('previous',axis=1)
tracks_df = tracks_df.drop('total',axis=1)
tracks_df
# Out:
#                                                  href  \
# 0   https://api.spotify.com/v1/me/tracks?offset=0&...
# 1   https://api.spotify.com/v1/me/tracks?offset=0&...
# 2   https://api.spotify.com/v1/me/tracks?offset=0&...
# 3   https://api.spotify.com/v1/me/tracks?offset=0&...
# 4   https://api.spotify.com/v1/me/tracks?offset=0&...
# 5   https://api.spotify.com/v1/me/tracks?offset=0&...
# 6   https://api.spotify.com/v1/me/tracks?offset=0&...
# 7   https://api.spotify.com/v1/me/tracks?offset=0&...
# 8   https://api.spotify.com/v1/me/tracks?offset=0&...
# 9   https://api.spotify.com/v1/me/tracks?offset=0&...
# 10  https://api.spotify.com/v1/me/tracks?offset=0&...
# 11  https://api.spotify.com/v1/me/tracks?offset=0&...
# 12  https://api.spotify.com/v1/me/tracks?offset=0&...
# 13  https://api.spotify.com/v1/me/tracks?offset=0&...
# 14  https://api.spotify.com/v1/me/tracks?offset=0&...
# 15  https://api.spotify.com/v1/me/tracks?offset=0&...
# 16  https://api.spotify.com/v1/me/tracks?offset=0&...
# 17  https://api.spotify.com/v1/me/tracks?offset=0&...
# 18  https://api.spotify.com/v1/me/tracks?offset=0&...
# 19  https://api.spotify.com/v1/me/tracks?offset=0&...
# 20  https://api.spotify.com/v1/me/tracks?offset=0&...
# 21  https://api.spotify.com/v1/me/tracks?offset=0&...
# 22  https://api.spotify.com/v1/me/tracks?offset=0&...
# 23  https://api.spotify.com/v1/me/tracks?offset=0&...
# 24  https://api.spotify.com/v1/me/tracks?offset=0&...
# 25  https://api.spotify.com/v1/me/tracks?offset=0&...
# 26  https://api.spotify.com/v1/me/tracks?offset=0&...
# 27  https://api.spotify.com/v1/me/tracks?offset=0&...
# 28  https://api.spotify.com/v1/me/tracks?offset=0&...
# 29  https://api.spotify.com/v1/me/tracks?offset=0&...
# 30  https://api.spotify.com/v1/me/tracks?offset=0&...
# 31  https://api.spotify.com/v1/me/tracks?offset=0&...
# 32  https://api.spotify.com/v1/me/tracks?offset=0&...
# 33  https://api.spotify.com/v1/me/tracks?offset=0&...
# 34  https://api.spotify.com/v1/me/tracks?offset=0&...
# 35  https://api.spotify.com/v1/me/tracks?offset=0&...
# 36  https://api.spotify.com/v1/me/tracks?offset=0&...
# 37  https://api.spotify.com/v1/me/tracks?offset=0&...
# 38  https://api.spotify.com/v1/me/tracks?offset=0&...
# 39  https://api.spotify.com/v1/me/tracks?offset=0&...
# 40  https://api.spotify.com/v1/me/tracks?offset=0&...
# 41  https://api.spotify.com/v1/me/tracks?offset=0&...
# 42  https://api.spotify.com/v1/me/tracks?offset=0&...
# 43  https://api.spotify.com/v1/me/tracks?offset=0&...
# 44  https://api.spotify.com/v1/me/tracks?offset=0&...
# 45  https://api.spotify.com/v1/me/tracks?offset=0&...
# 46  https://api.spotify.com/v1/me/tracks?offset=0&...
# 47  https://api.spotify.com/v1/me/tracks?offset=0&...
# 48  https://api.spotify.com/v1/me/tracks?offset=0&...
# 49  https://api.spotify.com/v1/me/tracks?offset=0&...
#
#                                                 items
# 0   {'added_at': '2019-10-15T23:39:26Z', 'track': ...
# 1   {'added_at': '2019-10-13T15:03:49Z', 'track': ...
# 2   {'added_at': '2019-10-13T04:18:04Z', 'track': ...
# 3   {'added_at': '2019-10-12T01:38:05Z', 'track': ...
# 4   {'added_at': '2019-10-10T18:56:53Z', 'track': ...
# 5   {'added_at': '2019-10-08T05:13:26Z', 'track': ...
# 6   {'added_at': '2019-10-08T04:44:08Z', 'track': ...
# 7   {'added_at': '2019-10-07T19:32:39Z', 'track': ...
# 8   {'added_at': '2019-10-07T16:30:00Z', 'track': ...
# 9   {'added_at': '2019-10-07T16:22:26Z', 'track': ...
# 10  {'added_at': '2019-10-07T15:16:08Z', 'track': ...
# 11  {'added_at': '2019-10-02T18:44:26Z', 'track': ...
# 12  {'added_at': '2019-09-30T17:14:56Z', 'track': ...
# 13  {'added_at': '2019-09-25T14:24:08Z', 'track': ...
# 14  {'added_at': '2019-09-23T13:55:57Z', 'track': ...
# 15  {'added_at': '2019-09-22T20:05:59Z', 'track': ...
# 16  {'added_at': '2019-09-16T15:17:18Z', 'track': ...
# 17  {'added_at': '2019-09-14T11:47:25Z', 'track': ...
# 18  {'added_at': '2019-09-13T22:12:07Z', 'track': ...
# 19  {'added_at': '2019-08-31T19:05:02Z', 'track': ...
# 20  {'added_at': '2019-08-31T19:01:02Z', 'track': ...
# 21  {'added_at': '2019-08-26T19:11:01Z', 'track': ...
# 22  {'added_at': '2019-08-14T19:43:34Z', 'track': ...
# 23  {'added_at': '2019-08-12T17:38:35Z', 'track': ...
# 24  {'added_at': '2019-08-11T13:50:49Z', 'track': ...
# 25  {'added_at': '2019-08-11T03:39:31Z', 'track': ...
# 26  {'added_at': '2019-08-06T17:32:48Z', 'track': ...
# 27  {'added_at': '2019-08-06T17:14:59Z', 'track': ...
# 28  {'added_at': '2019-08-06T16:12:17Z', 'track': ...
# 29  {'added_at': '2019-08-06T12:45:03Z', 'track': ...
# 30  {'added_at': '2019-08-06T12:44:54Z', 'track': ...
# 31  {'added_at': '2019-07-31T16:49:02Z', 'track': ...
# 32  {'added_at': '2019-07-29T21:53:19Z', 'track': ...
# 33  {'added_at': '2019-07-26T16:31:24Z', 'track': ...
# 34  {'added_at': '2019-07-25T18:30:37Z', 'track': ...
# 35  {'added_at': '2019-07-25T15:49:19Z', 'track': ...
# 36  {'added_at': '2019-07-24T19:49:09Z', 'track': ...
# 37  {'added_at': '2019-07-22T16:18:42Z', 'track': ...
# 38  {'added_at': '2019-07-19T15:12:52Z', 'track': ...
# 39  {'added_at': '2019-07-17T17:04:44Z', 'track': ...
# 40  {'added_at': '2019-07-10T19:20:15Z', 'track': ...
# 41  {'added_at': '2019-07-09T14:00:30Z', 'track': ...
# 42  {'added_at': '2019-07-08T14:43:00Z', 'track': ...
# 43  {'added_at': '2019-07-08T14:22:09Z', 'track': ...
# 44  {'added_at': '2019-07-08T14:08:44Z', 'track': ...
# 45  {'added_at': '2019-07-02T21:52:33Z', 'track': ...
# 46  {'added_at': '2019-07-01T19:59:16Z', 'track': ...
# 47  {'added_at': '2019-06-28T20:08:00Z', 'track': ...
# 48  {'added_at': '2019-06-24T14:06:21Z', 'track': ...
# 49  {'added_at': '2019-06-21T20:29:10Z', 'track': ...

# %%
#lists to hold the ids and artists of a track
ids = []
artists = []

#iterates throught the items column in data frame to extract the id and artist
#the id of the track can be used to get other atributes about the track
for track in tracks_df["items"]:
    ids.append(track.get('track').get('album').get('artists')[0].get('id'))
    artists.append(track.get('track').get('album').get('artists')[0].get('name'))

#adds the ids and artists to the dataframe
tracks_df["ids"] = ids
tracks_df["artist"] = artists
#takes out the items column from the data frame
tracks_df = tracks_df.drop('items',axis=1)
tracks_df
# Out:
#                                                  href                     ids  \
# 0   https://api.spotify.com/v1/me/tracks?offset=0&...  29mFfyTK9p5UIV5OW6owEj
# 1   https://api.spotify.com/v1/me/tracks?offset=0&...  5pUo3fmmHT8bhCyHE52hA6
# 2   https://api.spotify.com/v1/me/tracks?offset=0&...  7gAppWoH7pcYmphCVTXkzs
# 3   https://api.spotify.com/v1/me/tracks?offset=0&...  0xu4jAQQv7ZAqvFGdc9HgP
# 4   https://api.spotify.com/v1/me/tracks?offset=0&...  5JZ7CnR6gTvEMKX4g70Amv
# 5   https://api.spotify.com/v1/me/tracks?offset=0&...  5vBrKGOjN10BMwB0cJADj4
# 6   https://api.spotify.com/v1/me/tracks?offset=0&...  5vBrKGOjN10BMwB0cJADj4
# 7   https://api.spotify.com/v1/me/tracks?offset=0&...  6dn6x1XOng3LOAnfTjUn77
# 8   https://api.spotify.com/v1/me/tracks?offset=0&...  0xu4jAQQv7ZAqvFGdc9HgP
# 9   https://api.spotify.com/v1/me/tracks?offset=0&...  5fMUXHkw8R8eOP2RNVYEZX
# 10  https://api.spotify.com/v1/me/tracks?offset=0&...  3KwmxIhSe9UTSEF37kwngR
# 11  https://api.spotify.com/v1/me/tracks?offset=0&...  2qxJFvFYMEDqd7ui6kSAcq
# 12  https://api.spotify.com/v1/me/tracks?offset=0&...  6nxWCVXbOlEVRexSbLsTer
# 13  https://api.spotify.com/v1/me/tracks?offset=0&...  6L1XC7NrmgWRlwAeLJvVtA
# 14  https://api.spotify.com/v1/me/tracks?offset=0&...  0xu4jAQQv7ZAqvFGdc9HgP
# 15  https://api.spotify.com/v1/me/tracks?offset=0&...  0xu4jAQQv7ZAqvFGdc9HgP
# 16  https://api.spotify.com/v1/me/tracks?offset=0&...  4xnihxcoXWK3UqryOSnbw5
# 17  https://api.spotify.com/v1/me/tracks?offset=0&...  3GYvf7puxwkr51EYoD9E7D
# 18  https://api.spotify.com/v1/me/tracks?offset=0&...  7AzjETXRUKNRSJHMW9GIqd
# 19  https://api.spotify.com/v1/me/tracks?offset=0&...  2NjfBq1NflQcKSeiDooVjY
# 20  https://api.spotify.com/v1/me/tracks?offset=0&...  4npEfmQ6YuiwW1GpUmaq3F
# 21  https://api.spotify.com/v1/me/tracks?offset=0&...  6CwfuxIqcltXDGjfZsMd9A
# 22  https://api.spotify.com/v1/me/tracks?offset=0&...  20gsENnposVs2I4rQ5kvrf
# 23  https://api.spotify.com/v1/me/tracks?offset=0&...  4GNC7GD6oZMSxPGyXy4MNB
# 24  https://api.spotify.com/v1/me/tracks?offset=0&...  2NjfBq1NflQcKSeiDooVjY
# 25  https://api.spotify.com/v1/me/tracks?offset=0&...  1MIVXf74SZHmTIp4V4paH4
# 26  https://api.spotify.com/v1/me/tracks?offset=0&...  69GGBxA162lTqCwzJG5jLp
# 27  https://api.spotify.com/v1/me/tracks?offset=0&...  4zvNyLZGnTV3eD4tERC24F
# 28  https://api.spotify.com/v1/me/tracks?offset=0&...  0Ye4nfYAA91T1X56gnlXAA
# 29  https://api.spotify.com/v1/me/tracks?offset=0&...  6gK1Uct5FEdaUWRWpU4Cl2
# 30  https://api.spotify.com/v1/me/tracks?offset=0&...  6gK1Uct5FEdaUWRWpU4Cl2
# 31  https://api.spotify.com/v1/me/tracks?offset=0&...  246dkjvS1zLTtiykXe5h60
# 32  https://api.spotify.com/v1/me/tracks?offset=0&...  69GGBxA162lTqCwzJG5jLp
# 33  https://api.spotify.com/v1/me/tracks?offset=0&...  2zmrsXMHxagFz6vI2cD7r6
# 34  https://api.spotify.com/v1/me/tracks?offset=0&...  00TKPo9MxwZ0j4ooveIxWZ
# 35  https://api.spotify.com/v1/me/tracks?offset=0&...  5X4LWwbUFNzPkEas04uU82
# 36  https://api.spotify.com/v1/me/tracks?offset=0&...  0vqJkZ0RpLZixt3lTmD8vP
# 37  https://api.spotify.com/v1/me/tracks?offset=0&...  0LyfQWJT6nXafLPZqxe9Of
# 38  https://api.spotify.com/v1/me/tracks?offset=0&...  23fqKkggKUBHNkbKtXEls4
# 39  https://api.spotify.com/v1/me/tracks?offset=0&...  01y8iBZYk8aeNfPsuTVrAt
# 40  https://api.spotify.com/v1/me/tracks?offset=0&...  6RHKEd9dpzQ4c09x8Zdaxu
# 41  https://api.spotify.com/v1/me/tracks?offset=0&...  6cEuCEZu7PAE9ZSzLLc2oQ
# 42  https://api.spotify.com/v1/me/tracks?offset=0&...  4kYGAK2zu9EAomwj3hXkXy
# 43  https://api.spotify.com/v1/me/tracks?offset=0&...  2WzaAvm2bBCf4pEhyuDgCY
# 44  https://api.spotify.com/v1/me/tracks?offset=0&...  4K9OTkRXEFL6NDXFTqVmq9
# 45  https://api.spotify.com/v1/me/tracks?offset=0&...  4Rxn7Im3LGfyRkY2FlHhWi
# 46  https://api.spotify.com/v1/me/tracks?offset=0&...  4xnihxcoXWK3UqryOSnbw5
# 47  https://api.spotify.com/v1/me/tracks?offset=0&...  7eCmccnRwPmRnWPw61x6jM
# 48  https://api.spotify.com/v1/me/tracks?offset=0&...  7eCmccnRwPmRnWPw61x6jM
# 49  https://api.spotify.com/v1/me/tracks?offset=0&...  4QVBYiagIaa6ZGSPMbybpy
#
#               artist
# 0              SONIA
# 1         Liam Payne
# 2          The Vamps
# 3       Boy In Space
# 4               Lauv
# 5              bülow
# 6              bülow
# 7        AJ Mitchell
# 8       Boy In Space
# 9              Diplo
# 10             SHAED
# 11              Zedd
# 12             Flume
# 13       Sam Fischer
# 14      Boy In Space
# 15      Boy In Space
# 16       Sasha Sloan
# 17               Ren
# 18      Nina Nesbitt
# 19       Tones and I
# 20           Ava Max
# 21            MARINA
# 22         Sam Feldt
# 23     Lewis Capaldi
# 24       Tones and I
# 25             Mabel
# 26  The Chainsmokers
# 27          Biltmore
# 28              Mako
# 29     Petit Biscuit
# 30     Petit Biscuit
# 31       Post Malone
# 32  The Chainsmokers
# 33          Ella Vos
# 34             Loote
# 35             DVBBS
# 36           Whethan
# 37   Various Artists
# 38              Kygo
# 39              Sody
# 40         Clara Mae
# 41             R3HAB
# 42         JP Cooper
# 43           Ruth B.
# 44             Elina
# 45        Nick Jonas
# 46       Sasha Sloan
# 47        SHY Martin
# 48        SHY Martin
# 49        Pedro Capó

# %%
#saves tracks data frame to csv
tracks_df.to_csv("DS3000_50_saved_songs_data.csv")
